# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 10])
ypoints = np.array([0, 200]) 

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 10])
ypoints = np.array([0, 200])

plt.plot(xpoints, ypoints, "o")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([5, 10])
ypoints = np.array([10, 200])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([4, 10, 15, 2])
ypoints = np.array([10, 20, 3, 14])

plt.plot(xpoints, ypoints, "o")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([4, 10, 15, 2])
ypoints = np.array([10, 20, 3, 14])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([10, 20, 3, 14])

plt.plot(ypoints)
plt.show()

# %% [markdown]
# # MatplotLib Marker

# %%
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([10, 20, 3, 14])

plt.plot(ypoints, marker = "o")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([10, 20, 3, 14])

plt.plot(ypoints, marker = ".")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([10, 20, 3, 14])

plt.plot(ypoints, marker = "x")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([10, 20, 3, 14])

plt.plot(ypoints, marker = "P") #small = +
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([10, 20, 3, 14])

plt.plot(ypoints, marker = "s") 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([10, 20, 3, 14])

plt.plot(ypoints, marker = "|") 
plt.show()

# %% [markdown]
# ## Format String

# %%
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([10, 20, 3, 14])

plt.plot(ypoints, ">--r") 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([10, 20, 3, 14])

plt.plot(ypoints, ">-.r") 
plt.show()

# %% [markdown]
# ## Color Reference

# %%
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([10, 20, 3, 14])

plt.plot(ypoints, ">-.b") 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([10, 20, 3, 14])

plt.plot(ypoints, ">-.k") 
plt.show()

# %% [markdown]
# ## Marker Size

# %%
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([10, 20, 3, 14])

plt.plot(ypoints, marker = "s", ms = 10) 
plt.show()

# %% [markdown]
# ## Marker Color

# %%
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([10, 20, 3, 14])

plt.plot(ypoints, marker = "s", ms = 10, mec = "r") 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([10, 20, 3, 14])

plt.plot(ypoints, marker = "s", ms = 10, mfc = "r") 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([10, 20, 3, 14])

plt.plot(ypoints, marker = "o", ms = 10, mec = "r", mfc = "r") 
plt.show()

# %% [markdown]
# # Line Style

# %%
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([10, 20, 3, 14])

plt.plot(ypoints, linestyle = "dotted") 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([10, 20, 3, 14])

plt.plot(ypoints, linestyle = "dashed") 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([10, 20, 3, 14])

plt.plot(ypoints, ls = ":") 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([10, 20, 3, 14])

plt.plot(ypoints, color = "b") 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


ypoints = np.array([10, 20, 3, 14])

plt.plot(ypoints, linewidth = "5") 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([4, 8, 16, 20])
ypoints = np.array([2, 6, 14, 18])

plt.plot(xpoints)
plt.plot(ypoints) 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([4, 20])
ypoints = np.array([2, 18])

plt.plot(xpoints)
plt.plot(ypoints) 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([4, 20])
ypoints = np.array([2, 18])
xpoints1 = np.array([4, 20])
ypoints1 = np.array([2, 18])

plt.plot(xpoints, xpoints1, ypoints,ypoints1)
plt.show()

# %% [markdown]
# # Matplotlib Labels and Title

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([4, 20])
y = np.array([2, 18])
plt.ylabel("Blake is an old man")
plt.xlabel("Pablo is a young man")


plt.plot(x)
plt.plot(y) 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([4, 20])
y = np.array([2, 18])
plt.ylabel("Blake is an old man")
plt.xlabel("Pablo is a young man")
plt.title("Kingsley Chika CHUKWU")


plt.plot(x)
plt.plot(y) 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([4, 20])
y = np.array([2, 18])

font1 = {"family":"arial", "color": "green", "size": 20}
font2 = {"family":"serif", "color": "black", "size": 10}

plt.ylabel("Blake is an old man", fontdict = font2)
plt.xlabel("Pablo is a young man",  fontdict = font2)
plt.title("Kingsley Chika CHUKWU",  fontdict = font1)


plt.plot(x)
plt.plot(y) 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([4, 20])
y = np.array([2, 18])

font1 = {"family":"arial", "color": "green", "size": 20}
font2 = {"family":"serif", "color": "black", "size": 10}

plt.ylabel("Blake is an old man", fontdict = font2)
plt.xlabel("Pablo is a young man",  fontdict = font2)
plt.title("Kingsley Chika CHUKWU",  fontdict = font1, loc = "right")


plt.plot(x)
plt.plot(y) 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x = np.array([4, 10, 15, 2])
y = np.array([10, 20, 15, 10])

font1 = {"family":"arial", "color": "green", "size": 20}
font2 = {"family":"serif", "color": "black", "size": 10}

plt.ylabel("Blake is an old man", fontdict = font2)
plt.xlabel("Pablo is a young man",  fontdict = font2)
plt.title("Kingsley Chika CHUKWU",  fontdict = font1, loc = "right")


plt.plot(x)
plt.plot(y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Font
font1 = {"family":"arial", "color": "blue", "size": 20}

#Easting and Northing
Easting = np.array([2, 2, 13, 13, 2])
Northing = np.array([10, 20, 20, 10, 10])

#Road
road = np.array([7, 25])

#Plotting
plt.plot(Easting, Northing, marker="s", color = "r")
plt.plot(road, ls = ":", color = "k")
plt.title("Kingsley Chika CHUKWU",  fontdict = font1, loc = "right")
plt.show()

# %% [markdown]
# ## Assignment 1

# %%
import matplotlib.pyplot as plt
import numpy as np

# Font
font1 = {"family":"arial", "color": "blue", "size": 20}

#Easting and Northing
Easting = np.array([2, 2, 13, 13, 2])
Northing = np.array([10, 20, 20, 10, 10])

#Road
road = np.array([7, 25])

#Plotting
plt.plot(Easting, Northing, marker="s", color = "r")
plt.plot(road, ls = ":", color = "k")
plt.title("Kingsley Chika CHUKWU",  fontdict = font1, loc = "right")
plt.show()

# %% [markdown]
# # Matplotlib Grid

# %%
import matplotlib.pyplot as plt
import numpy as np

# Font
font1 = {"family":"arial", "color": "blue", "size": 20}

#Easting and Northing
Easting = np.array([2, 2, 13, 13, 2])
Northing = np.array([10, 20, 20, 10, 10])

#Road
road = np.array([7, 25])

#Plotting
plt.plot(Easting, Northing, marker="s", color = "r")
plt.plot(road, ls = ":", color = "k")
plt.title("Kingsley Chika CHUKWU",  fontdict = font1, loc = "right")
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Font
font1 = {"family":"arial", "color": "blue", "size": 20}

#Easting and Northing
Easting = np.array([2, 2, 13, 13, 2])
Northing = np.array([10, 20, 20, 10, 10])

#Road
road = np.array([7, 25])

#Plotting
plt.plot(Easting, Northing, marker="s", color = "r")
plt.plot(road, ls = ":", color = "k")
plt.title("Kingsley Chika CHUKWU",  fontdict = font1, loc = "right")
plt.grid(axis = "y")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Font
font1 = {"family":"arial", "color": "blue", "size": 20}

#Easting and Northing
Easting = np.array([2, 2, 13, 13, 2])
Northing = np.array([10, 20, 20, 10, 10])

#Road
road = np.array([7, 25])

#Plotting
plt.plot(Easting, Northing, marker="s", color = "r")
plt.plot(road, ls = ":", color = "k")


plt.title("Kingsley Chika CHUKWU",  fontdict = font1, loc = "right")

plt.grid(color = "gray", linestyle = "--", linewidth = 0.5)
plt.show()

# %% [markdown]
# # Matplotlib Subplot

# %%
import matplotlib.pyplot as plt
import numpy as np

#  Plot 1
x = np.array([4, 20])
y = np.array([2, 18])
plt.ylabel("Blake is an old man")
plt.xlabel("Pablo is a young man")
plt.title("Kingsley Chika CHUKWU")

plt.subplot(2,1,2) # 2 = row, 1 = column, 2 = loc
plt.plot(x)
plt.plot(y) 


# Plot 2
#Easting and Northing
Easting = np.array([2, 2, 13, 13, 2])
Northing = np.array([10, 20, 20, 10, 10])

plt.subplot(2,1,1)
plt.plot(Easting, Northing, marker="s", color = "r")
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#  Plot 1
x = np.array([4, 20])
y = np.array([2, 18])
plt.ylabel("Blake is an old man")
plt.xlabel("Pablo is a young man")
plt.title("Kingsley Chika CHUKWU")

plt.subplot(1,2,2) # 2 = row, 1 = column, 2 = loc
plt.plot(x)
plt.plot(y) 


# Plot 2
#Easting and Northing
Easting = np.array([2, 2, 13, 13, 2])
Northing = np.array([10, 20, 20, 10, 10])

plt.subplot(1,2,1)
plt.plot(Easting, Northing, marker="s", color = "r")
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#  Plot 1
x = np.array([4, 20])
y = np.array([2, 18])
plt.ylabel("Blake is an old man")
plt.xlabel("Pablo is a young man")
plt.title("Kingsley Chika CHUKWU")

plt.subplot(3,2,1) # 2 = row, 1 = column, 2 = loc
plt.plot(x)
plt.plot(y) 


# Plot 2
#Easting and Northing
Easting = np.array([2, 2, 13, 13, 2])
Northing = np.array([10, 20, 20, 10, 10])
plt.subplot(3,2,2)
plt.plot(Easting, Northing, marker="s", color = "r")

# Plot 3
x = np.array([5, 12])
y = np.array([21, 8])
plt.subplot(3,2,3)
plt.plot(x, y)

#Plot 4 
x = np.array([2, 4])
y = np.array([8, 12])
plt.subplot(3,2,5)
plt.plot(x, y)

#plot 5
x = np.array([21,14])
y = np.array([81, 2])
plt.subplot(3,2,6)
plt.plot(x, y)

# Plot 6
#plot 5
x = np.array([21,14, 7])
y = np.array([8, 6, 4])
plt.subplot(3,2,4)
plt.plot(x, y)


plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#  Plot 1
x = np.array([4, 20])
y = np.array([2, 18])
plt.ylabel("Blake is an old man")
plt.xlabel("Pablo is a young man")
plt.title("Kingsley Chika CHUKWU")

plt.subplot(2,3,1) # 2 = row, 1 = column, 2 = loc
plt.plot(x)
plt.plot(y) 


# Plot 2
#Easting and Northing
Easting = np.array([2, 2, 13, 13, 2])
Northing = np.array([10, 20, 20, 10, 10])
plt.subplot(2,3,2)
plt.plot(Easting, Northing, marker="s", color = "r")

# Plot 3
x = np.array([5, 12])
y = np.array([21, 8])
plt.subplot(2,3,3)
plt.plot(x, y)

#Plot 4 
x = np.array([2, 4])
y = np.array([8, 12])
plt.subplot(2,3,5)
plt.plot(x, y)

#plot 5
x = np.array([21,14])
y = np.array([81, 2])
plt.subplot(2,3,6)
plt.plot(x, y)

# Plot 6
#plot 5
x = np.array([21,14, 7])
y = np.array([8, 6, 4])
plt.subplot(2,3,4)
plt.plot(x, y)
plt.grid()

plt.suptitle("Kingsley Chika CHUKWU")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


plt.ylabel("Blake is an old man")
plt.xlabel("Pablo is a young man")


#  Plot 1
x = np.array([4, 20])
y = np.array([2, 18])
plt.subplot(2,3,1) # 2 = row, 1 = column, 2 = loc
plt.plot(x)
plt.plot(y) 
plt.title("Blake")
plt.grid()


# Plot 2
Easting = np.array([2, 2, 13, 13, 2])
Northing = np.array([10, 20, 20, 10, 10])
plt.subplot(2,3,2)
plt.plot(Easting, Northing, marker="s", color = "r")
plt.title("Collins")
plt.grid()


# Plot 3
x = np.array([5, 12])
y = np.array([21, 8])
plt.subplot(2,3,3)
plt.plot(x, y)
plt.title("Kingsley")
plt.grid()

#Plot 4 
x = np.array([2, 4])
y = np.array([8, 12])
plt.subplot(2,3,5)
plt.plot(x, y)
plt.title("Pablo")
plt.grid()

#plot 5
x = np.array([21,14])
y = np.array([81, 2])
plt.subplot(2,3,6)
plt.plot(x, y)
plt.title("Sterling")
plt.grid()

# Plot 6
#plot 5
x = np.array([21,14, 7])
y = np.array([8, 6, 4])
plt.subplot(2,3,4)
plt.plot(x, y)
plt.title("Steph")
plt.grid()

plt.suptitle("Kingsley Chika CHUKWU")
plt.show()

# %% [markdown]
# # Assignment 2

# %%
import matplotlib.pyplot as plt
import numpy as np


plt.ylabel("Y Axis")
plt.xlabel("X Axis")


#  Plot 1
x = np.array([4, 15, 35, 120])
plt.subplot(2,3,1) 
plt.plot(x)
plt.title("Blake")
plt.grid(axis = "x")


# Plot 2
long = np.array([2, 2, 13, 13, 2])
lat = np.array([10, 20, 20, 10, 10])
plt.subplot(2,3,2)
plt.plot(long, lat, marker="s", color = "b")
plt.title("Collins")
plt.grid()


# Plot 3
y = np.array([21, 8, 15, 77, 13])
plt.subplot(2,3,3)
plt.plot(y, color = "r")
plt.title("Stella")
plt.grid(axis = "y")

#Plot 4 
x = np.array([-2, -4, 10])
y = np.array([-8, 12, -1])
plt.subplot(2,3,4)
plt.plot(x, y, color = "y")
plt.title("Pablo")

#plot 5
x = np.array([21, 7, 14, 5, 16, 6, 32, 19])
y = np.array([81, 65, 2, 8, 6, 12, 16, 9])
plt.subplot(2,3,5)
plt.plot(x, y, color = "g")
plt.title("Sterling")

# Plot 6
x = np.array([21,14, 7])
y = np.array([8, 6, 4])
plt.subplot(2,3,6)
plt.plot(x, y)
plt.title("Steph")
plt.grid()

plt.suptitle("Ezie Victor Erus Graph")
plt.show()

# %% [markdown]
# # Matplotlib Scatter

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.array([2,4,6,7,8,10,3,5,7,3,15])
y= np.array([12,42,6,47,8,10,3,15,7,13,15])
plt.scatter(x,y)


plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.array([2,4,6,7,8,10,3,5,7,3,15])
y= np.array([12,42,6,47,8,10,3,15,7,13,15])
plt.scatter(x,y)

x= np.array([4,6,8,1,0,6])
y= np.array([2,5,12,10,20,16])
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.array([2,4,6,7,8,10,3,5,7,3,15])
y= np.array([12,42,6,47,8,10,3,15,7,13,15])
plt.scatter(x,y, color ="k")

x= np.array([4,6,8,1,0,6])
y= np.array([2,5,12,10,20,16])
plt.scatter(x,y, color = "green")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.array([4,6,8,1,0,6])
y= np.array([2,5,12,10,20,16])
colors = np.array(["red", "green", "blue", "cyan", "black", "yellow"])
plt.scatter(x,y, c = colors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.array([4,6,8,1,0,6])
y= np.array([2,5,12,10,20,16])
colors = np.array([0, 10, 20, 30, 40, 50])
plt.scatter(x,y, c = colors, cmap = "viridis")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.array([4,6,8,1,0,6])
y= np.array([2,5,12,10,20,16])
colors = np.array([0, 10, 20, 30, 40, 50])
plt.scatter(x,y, c = colors, cmap = "viridis")
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.array([4,6,8,1,0,6])
y= np.array([2,5,12,10,20,16])
colors = np.array([0, 10, 20, 30, 40, 50])
plt.scatter(x,y, c = colors, cmap = "Accent")
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.array([4,6,8,1,0,6])
y= np.array([2,5,12,10,20,16])
colors = np.array([0, 10, 20, 30, 40, 50])
plt.scatter(x,y, c = colors, cmap = "Blues")
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.array([4,6,8,1,0,6])
y= np.array([2,5,12,10,20,16])
colors = np.array([0, 10, 20, 30, 40, 50])
plt.scatter(x,y, c = colors, cmap = "Reds")
plt.colorbar()
plt.show()

# %% [markdown]
# # Size

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.array([4,6,8,1,0,6])
y= np.array([2,5,12,10,20,16])
size = np.array([10, 100, 200, 300, 400, 500])
plt.scatter(x,y, s = size)
plt.colorbar()
plt.show()

# %% [markdown]
# # Alpha

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.array([4,6,8,1,0,6])
y= np.array([2,5,12,10,20,16])
size = np.array([10, 100, 200, 300, 400, 500])
plt.scatter(x,y, s = size, alpha = 0.5)
plt.colorbar()
plt.show()

# %% [markdown]
# # Combine Color Size and Alpha

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.random.randint(100, size= (100))
y= np.random.randint(100, size= (100))
colors = np.random.randint(100, size= (100))
sizes = np.random.randint(100, size= (100))

plt.scatter(x,y, c = colors, s = sizes, alpha = 0.5, cmap = "ocean")
plt.colorbar()
plt.show()

# %% [markdown]
# # Assignment on scatter Plot

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([
    0.1569, 0.8743, 0.3917, 0.2870, 0.9984, 0.6111, 0.4552, 0.7683, 0.5781, 0.0511,
    0.3154, 0.1453, 0.7602, 0.6851, 0.2864, 0.5192, 0.6549, 0.9375, 0.3242, 0.7558,
    0.2735, 0.4964, 0.3894, 0.8407, 0.7101, 0.1681, 0.6324, 0.5684, 0.4361, 0.1576,
    0.6631, 0.7922, 0.4205, 0.2452, 0.7244, 0.5129, 0.1748, 0.8511, 0.9417, 0.3171,
    0.4924, 0.7039, 0.4053, 0.8974, 0.6081, 0.2106, 0.3591, 0.2804, 0.4967, 0.1384
])

y = np.array([
    0.8473, 0.1329, 0.4327, 0.5607, 0.2094, 0.4371, 0.6159, 0.9320, 0.7306, 0.3491,
    0.7429, 0.6513, 0.4821, 0.3064, 0.8704, 0.5763, 0.1235, 0.8476, 0.2871, 0.9362,
    0.6394, 0.7384, 0.5487, 0.1924, 0.5683, 0.2937, 0.8415, 0.4708, 0.5120, 0.7462,
    0.3764, 0.8904, 0.1328, 0.4962, 0.3198, 0.7483, 0.3642, 0.2104, 0.4392, 0.9834,
    0.5623, 0.3876, 0.5294, 0.2471, 0.4081, 0.6534, 0.7812, 0.9021, 0.3541, 0.6738
])

colors = np.random.rand(50) 

plt.scatter(x, y, c=colors, cmap='viridis')
plt.title("Correlation Analysis on the Pre_Event and Post_Event")
plt.xlabel("Pre_Event")
plt.ylabel("Post_Event")
plt.colorbar()
plt.show()

# %% [markdown]
# # Matplotlib Bar

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Collins", "Blake", "Nulu", "Steph"])
y = np.array([4, 13, 5,9])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Collins", "Blake", "Nulu", "Steph"])
y = np.array([4, 13, 5,9])

plt.barh(x,y)
plt.show()

# %% [markdown]
# ## Bar Color

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Collins", "Blake", "Nulu", "Steph"])
y = np.array([4, 13, 5,9])

plt.bar(x,y, color = "green")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Collins", "Blake", "Nulu", "Steph"])
y = np.array([4, 13, 5,9])

plt.barh(x,y, color = "black")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Collins", "Blake", "Nulu", "Steph"])
y = np.array([4, 13, 5,9])

plt.barh(x,y, color = "hotpink")
plt.show()

# %% [markdown]
# ##  Bar Color (Hexadeciaml)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Collins", "Blake", "Nulu", "Steph"])
y = np.array([4, 13, 5,9])

plt.barh(x,y, color = "#5B19EB")
plt.show()

# %% [markdown]
# ## Bar Width

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Collins", "Blake", "Nulu", "Steph"])
y = np.array([4, 13, 5,9])

plt.bar(x,y, width = 0.8, color = "#5B19EB")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Collins", "Blake", "Nulu", "Steph"])
y = np.array([4, 13, 5,9])

plt.barh(x,y, height = 0.9, color = "#5B19EB")
plt.show()

# %% [markdown]
# # Matplotlib Histogram

# %%
import numpy as np

x = np.random.normal(100, 10, 100)
# First = value to concertrate, Second = SD  , Third = How many Value
print(x)
# Out:
# [ 99.49527108  94.11004398  95.50124883 100.85162115  94.53333101
#  113.65418147 103.26971965  93.8980605   91.01312896  98.76494629
#  103.97124596 110.22339746  94.58452143 102.22367947 102.23852325
#  101.72594948  80.28176547 113.57971806  88.59406502 108.07197451
#  112.40217184 106.45283885 108.30884591 111.85694388 105.86331859
#   95.46565003  95.84078623 101.55707843  95.26885328 101.98745556
#  112.92362633  93.11473738  66.33887737  91.82153892  87.05156266
#   96.68208815  95.76140872 115.92507592  99.36582343 103.89342288
#   82.6579946  109.68922227  92.62660555  96.55136605  91.72983809
#   90.35260946 102.39184652  93.88927052 108.28858324  85.67708054
#  105.38941747 109.672579    94.32717746  95.38393179  95.12924027
#   84.06301465  91.55698551 123.78172952  87.56084786  79.68880138
#   90.08316459  98.60045255 105.65104434  97.36517326 115.48300958
#  115.53719188  83.26061469 109.48440082 103.10257339 108.68977064
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(100, 10, 100)
plt.hist(x)
plt.show()

# %% [markdown]
# # Matplotlib Creating Pie Chart

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([180,45 ,45 ,45 ,45]) # x /sum(X) formula
plt.pie(x)
plt.show()

# %% [markdown]
# # Pie Label

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([90,45 ,45 ,45 ,45]) 
mylabels = ["Steph", "Pablo", "Nulu", "Stella", "Sterling"]
plt.pie(x, labels = mylabels)
plt.show()

# %% [markdown]
# ##  Start Angle

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([90,45 ,45 ,45 ,45]) 
mylabels = ["Steph", "Pablo", "Nulu", "Stella", "Sterling"]

plt.pie(x, labels = mylabels, startangle= 45)
plt.show()

# %% [markdown]
# ## Explode

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([90,45 ,45 ,45 ,45]) 
mylabels = ["Steph", "Pablo", "Nulu", "Stella", "Sterling"]
myexplode= [0, 0.2, 0, 0.2, 0]

plt.pie(x, labels = mylabels, startangle= 0, explode = myexplode)
plt.show()

# %% [markdown]
# ## Shadow

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([90,45 ,45 ,45 ,45]) 
mylabels = ["Steph", "Pablo", "Nulu", "Stella", "Sterling"]
myexplode= [0, 1, 0, 0.2, 1]

plt.pie(x, labels = mylabels, startangle= 0, explode = myexplode, shadow = True)
plt.show()

# %% [markdown]
# # Color

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([90,45 ,45 ,45 ,45]) 
mylabels = ["Steph", "Pablo", "Nulu", "Stella", "Sterling"]
myexplode= [0, 0.2, 0, 0.2, 0.3]
mycolor = ["black", "blue", "green", "yellow", "red"]
plt.pie(x, labels = mylabels, startangle= 0, explode = myexplode, shadow = True, colors = mycolor)
plt.show()

# %% [markdown]
# ## Legend

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([90,45 ,45 ,45 ,45]) 
mylabels = ["Steph", "Pablo", "Nulu", "Stella", "Sterling"]
myexplode= [0, 0.2, 0, 0.2, 0.3]
mycolor = ["black", "blue", "green", "yellow", "red"]
plt.pie(x, labels = mylabels, startangle= 0, explode = myexplode, shadow = True, colors = mycolor)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([90,45 ,45 ,45 ,45]) 
mylabels = ["Steph", "Pablo", "Nulu", "Stella", "Sterling"]
myexplode= [0, 0.2, 0, 0.2, 0.3]
mycolor = ["black", "blue", "green", "yellow", "red"]
plt.pie(x, labels = mylabels, startangle= 0, explode = myexplode, shadow = True, colors = mycolor)
plt.legend(title = "Begineers")
plt.show()
