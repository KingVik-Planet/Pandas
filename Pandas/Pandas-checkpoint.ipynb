# %%
import pandas as pd
df = pd.DataFrame(
    {
        "Name": [
            "Kingsley",
            "Chika",
            "CHUKWU",
        ],
        "Age": [12, 45, 34],
        "State": ["Ebonyi", "Enugu", "Abia"],
    }
)
print(df)
# Out:
#        Name  Age   State
# 0  Kingsley   12  Ebonyi
# 1     Chika   45   Enugu
# 2    CHUKWU   34    Abia

# %%
df["Age"]
# Out:
# 0    12
# 1    45
# 2    34
# Name: Age, dtype: int64

# %%
df["Age"].sum()
# Out:
# np.int64(91)

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   30.333333
# std    16.802778
# min    12.000000
# 25%    23.000000
# 50%    34.000000
# 75%    39.500000
# max    45.000000

# %%
df.head()
# Out:
#        Name  Age   State
# 0  Kingsley   12  Ebonyi
# 1     Chika   45   Enugu
# 2    CHUKWU   34    Abia

# %%
data = pd.read_csv("Data/nigeriahealthfacilities.csv")

# %%
data.head()
# Out:
#    id                        name                             global_id  \
# 0   1          G R A Nursing Home  af719462-abfd-4f47-9dc3-0987164e75ac
# 1   2       Gishili Health Center  a29b0328-d844-4358-b0ab-2e120b8fb30f
# 2   3  Lehobi Primary Health Care  b685b769-5c83-4f83-a182-00e7e1b777d8
# 3   4              Dugja Idp Camp  78e64f7a-cbb8-4357-9e64-a7e502534527
# 4   5   Kopa Maikudiri Dispensary  409c97ce-7490-4dc2-a8f8-2b8d53ad2b12
#
#              alternate_name     functional_status     type ward_code  \
# 0              Nursing Home               Unknown  Primary     12413
# 1              Nursing Home            Functional  Primary     12413
# 2                       NaN  Partially Functional  Primary     10207
# 3  Mandara Girau Dispensary        Not Functional  Primary     10503
# 4                       NaN  Partially Functional  Primary     10209
#
#                 category             timestamp accessibility    lga_name  \
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\chukw\\PycharmProjects\\Pandas'

# %%
os.chdir("C:\\Users\\chukw\\PycharmProjects\\Pandas")

# %%
data.tail()
# Out:
#           id                                  name  \
# 46141  46604                         Lafiya Clinic
# 46142  46605  Ardo Kola Primary Health Care Center
# 46143  46606        Ke Comprehensive Health Center
# 46144  46607           Bonny Primary Health Center
# 46145  46608            Ukpe Primary Health Center
#
#                                   global_id alternate_name functional_status  \
# 46141  350ef859-fe87-440e-ae8e-2272520e242f            NaN           Unknown
# 46142  bd59e8e3-80a8-4239-8bbb-4e4c0f648c54            NaN        Functional
# 46143  ef14c01b-bc46-4a5c-b61e-4f1634ba5a46            NaN           Unknown
# 46144  1e11690d-0a3b-4dbd-b379-8789f350affc            NaN        Functional
# 46145  3f74184b-589f-4edb-815d-140ff020b456            NaN           Unknown
#
#           type ward_code                     category             timestamp  \
# 46141  Primary  TRSARD05        Primary Health Center  2019-11-15T17:34:16Z
# ...

# %%
data.dtypes
# Out:
# id                    int64
# name                 object
# global_id            object
# alternate_name       object
# functional_status    object
# type                 object
# ward_code            object
# category             object
# timestamp            object
# accessibility        object
# lga_name             object
# lga_code              int64
# state_code           object
# state_name           object
# FID                  object
# dtype: object

# %%
state = data["category"]
state.tail(10)
# Out:
# 46136                 Maternity Home
# 46137          Primary Health Center
# 46138          Primary Health Center
# 46139          Primary Health Center
# 46140          Primary Health Center
# 46141          Primary Health Center
# 46142          Primary Health Center
# 46143    Comprehensive Health Center
# 46144          Primary Health Center
# 46145          Primary Health Center
# Name: category, dtype: object

# %%
type(data["name"])
# Out:
# pandas.core.series.Series

# %%
data["name"].shape
# Out:
# (46146,)

# %%
name_state = data[["name", "type"]]
name_state.head()
# Out:
#                          name     type
# 0          G R A Nursing Home  Primary
# 1       Gishili Health Center  Primary
# 2  Lehobi Primary Health Care  Primary
# 3              Dugja Idp Camp  Primary
# 4   Kopa Maikudiri Dispensary  Primary

# %%
data[["name", "type"]].shape
# Out:
# (46146, 2)

# %%
Type = data[data["functional_status"] == "Not Functional"]
Type.head(1)
# Out:
#    id            name                             global_id  \
# 3   4  Dugja Idp Camp  78e64f7a-cbb8-4357-9e64-a7e502534527
#
#              alternate_name functional_status     type ward_code  \
# 3  Mandara Girau Dispensary    Not Functional  Primary     10503
#
#                 category             timestamp accessibility lga_name  \
# 3  Primary Health Center  2020-07-04T13:49:18Z       Unknown      Biu
#
#    lga_code state_code state_name  \
# 3       105         BR      Borno
#
#                                                  FID
# 3  sv_health_facilities.fid--3185df38_17a314b4ee6...

# %%
data[data["functional_status"] == "Not Functional"].shape
# Out:
# (104, 15)

# %%
lga = data[data["lga_code"] == 101]
lga.head()
# Out:
#       id                          name                             global_id  \
# 10    11        Kangarwa Health Clinic  9084ffc4-0fa7-48e9-abdf-6340bf8881cd
# 33    34       Tumbun Guni Health Post  7ac23f05-af3c-46b6-9cd5-dcc9190d4be4
# 101  101        Yawa Veterinary Clinic  e02e50bf-6899-4a33-a803-e179f51a926b
# 149  149  Mallam Kaunari Health Clinic  ba9a01fe-c8cb-4427-92e9-db3658284a52
# 174  174             Busuna Dispensary  a1d5836e-60b9-4637-84d1-f7091047cd48
#
#                    alternate_name functional_status     type ward_code  \
# 10   Cocin Rural Health Programme    Not Functional  Primary     10111
# 33                            NaN    Not Functional  Primary     10101
# 101                           NaN           Unknown  Primary     10109
# 149                           NaN        Functional  Primary     10111
# 174                           NaN           Unknown  Primary     10111
#
#                   category             timestamp accessibility lga_name  \
# ...

# %%
data[data["lga_code"] == 101].shape
# Out:
# (13, 15)

# %%
data["lga_code"]==102
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 46141    False
# 46142    False
# 46143    False
# 46144    False
# 46145    False
# Name: lga_code, Length: 46146, dtype: bool

# %%
classxx = data[data["lga_code"].isin ([ 102, 1])]

# %%
classxx.head()
# Out:
#     id                        name                             global_id  \
# 2    3  Lehobi Primary Health Care  b685b769-5c83-4f83-a182-00e7e1b777d8
# 4    5   Kopa Maikudiri Dispensary  409c97ce-7490-4dc2-a8f8-2b8d53ad2b12
# 9   10        Uba Bobo Health Post  5a3864b5-d66b-4683-90cd-9c76af393450
# 15  16  Ngulde Primary Health Care  cfe845eb-9f71-4b99-9603-d2f389a73ba0
# 75  76            Dille Dispensary  b3580a0a-6fce-493e-bb67-515737f93efc
#
#    alternate_name     functional_status     type ward_code  \
# 2             NaN  Partially Functional  Primary     10207
# 4             NaN  Partially Functional  Primary     10209
# 9             NaN            Functional  Primary     10211
# 15            NaN            Functional  Primary     10208
# 75            NaN            Functional  Primary     10212
#
#                  category             timestamp accessibility    lga_name  \
# 2   Primary Health Center  2020-07-04T13:49:18Z           NaN  Askira Uba
# ...

# %%
state_name = data.loc[data["lga_code"] == 13016, "timestamp"]
state_name.head()
# Out:
# 6626    2019-11-15T17:29:44Z
# 8164    2019-06-14T10:17:38Z
# 8165    2019-06-14T10:17:38Z
# 8625    2019-11-15T17:15:50Z
# 9401    2019-11-15T17:15:50Z
# Name: timestamp, dtype: object

# %%
data.iloc[0:5, 7:8]
# Out:
#                 category
# 0  Primary Health Center
# 1  Primary Health Center
# 2  Primary Health Center
# 3  Primary Health Center
# 4             Dispensary

# %%
data.iloc[1:12,6] = "Pablo"
data.head(11)
# Out:
#     id                            name                             global_id  \
# 0    1                           Pablo                        Kingsley Chika
# 1    2           Gishili Health Center                        Kingsley Chika
# 2    3      Lehobi Primary Health Care                        Kingsley Chika
# 3    4                  Dugja Idp Camp  78e64f7a-cbb8-4357-9e64-a7e502534527
# 4    5       Kopa Maikudiri Dispensary  409c97ce-7490-4dc2-a8f8-2b8d53ad2b12
# 5    6        Ghumtukum Medical Center  6afd9e7a-b985-4cd5-b0cf-f9488500a3a0
# 6    7                Ghung Dispensary  50e5c971-d348-4c81-ba29-f806eefe9920
# 7    8           Grem Demch Dispensary  f92b67cf-d74c-4e37-8f8b-aa4e4b18f82d
# 8    9  Gumsuri Federal Medical Center  9c2b58dd-1e99-49b9-970e-eabce1c7dd10
# 9   10            Uba Bobo Health Post  5a3864b5-d66b-4683-90cd-9c76af393450
# 10  11          Kangarwa Health Clinic  9084ffc4-0fa7-48e9-abdf-6340bf8881cd
#
# ...
